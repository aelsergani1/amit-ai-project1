# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
data=pd.read_excel('Telco_customer_churn.xlsx')
data.head()
# Out:
#    CustomerID  Count        Country       State         City  Zip Code  \
# 0  3668-QPYBK      1  United States  California  Los Angeles     90003
# 1  9237-HQITU      1  United States  California  Los Angeles     90005
# 2  9305-CDSKC      1  United States  California  Los Angeles     90006
# 3  7892-POOKP      1  United States  California  Los Angeles     90010
# 4  0280-XJGEX      1  United States  California  Los Angeles     90015
#
#                  Lat Long   Latitude   Longitude  Gender  ...        Contract  \
# 0  33.964131, -118.272783  33.964131 -118.272783    Male  ...  Month-to-month
# 1   34.059281, -118.30742  34.059281 -118.307420  Female  ...  Month-to-month
# 2  34.048013, -118.293953  34.048013 -118.293953  Female  ...  Month-to-month
# 3  34.062125, -118.315709  34.062125 -118.315709  Female  ...  Month-to-month
# 4  34.039224, -118.266293  34.039224 -118.266293    Male  ...  Month-to-month
#
#   Paperless Billing             Payment Method  Monthly Charges Total Charges  \
# 0               Yes               Mailed check            53.85        108.15
# 1               Yes           Electronic check            70.70        151.65
# 2               Yes           Electronic check            99.65         820.5
# 3               Yes           Electronic check           104.80       3046.05
# 4               Yes  Bank transfer (automatic)           103.70        5036.3
#
#   Churn Label Churn Value Churn Score  CLTV                   Churn Reason
# 0         Yes           1          86  3239   Competitor made better offer
# 1         Yes           1          67  2701                          Moved
# 2         Yes           1          86  5372                          Moved
# 3         Yes           1          84  5003                          Moved
# 4         Yes           1          89  5340  Competitor had better devices
#
# [5 rows x 33 columns]

# %%
def data_info(data):
    cols=[]
    unique_val=[]
    n_uniques=[]
    dtypes=[]
    nulls=[]
    for col in data.columns:
        cols.append(col)
        dtypes.append(data[col].dtype)
        n_uniques.append(data[col].nunique())
        unique_val.append(data[col].unique())
        nulls.append(data[col].isna().sum())
        
    return pd.DataFrame({"Col":cols,"dtype":dtypes,"n_uniques":n_uniques,"Unique Values":unique_val,"Nulls":nulls})

# %%
data_info(data)
# Out:
#                   Col    dtype  n_uniques  \
# 0          CustomerID   object       7043
# 1               Count    int64          1
# 2             Country   object          1
# 3               State   object          1
# 4                City   object       1129
# 5            Zip Code    int64       1652
# 6            Lat Long   object       1652
# 7            Latitude  float64       1652
# 8           Longitude  float64       1651
# 9              Gender   object          2
# 10     Senior Citizen   object          2
# 11            Partner   object          2
# 12         Dependents   object          2
# 13      Tenure Months    int64         73
# 14      Phone Service   object          2
# 15     Multiple Lines   object          3
# 16   Internet Service   object          3
# 17    Online Security   object          3
# 18      Online Backup   object          3
# 19  Device Protection   object          3
# 20       Tech Support   object          3
# 21       Streaming TV   object          3
# 22   Streaming Movies   object          3
# 23           Contract   object          3
# 24  Paperless Billing   object          2
# 25     Payment Method   object          4
# 26    Monthly Charges  float64       1585
# 27      Total Charges   object       6531
# 28        Churn Label   object          2
# 29        Churn Value    int64          2
# 30        Churn Score    int64         85
# 31               CLTV    int64       3438
# 32       Churn Reason   object         20
#
#                                         Unique Values  Nulls
# 0   [3668-QPYBK, 9237-HQITU, 9305-CDSKC, 7892-POOK...      0
# 1                                                 [1]      0
# 2                                     [United States]      0
# 3                                        [California]      0
# 4   [Los Angeles, Beverly Hills, Huntington Park, ...      0
# 5   [90003, 90005, 90006, 90010, 90015, 90020, 900...      0
# 6   [33.964131, -118.272783, 34.059281, -118.30742...      0
# 7   [33.964131, 34.059281, 34.048013, 34.062125, 3...      0
# 8   [-118.272783, -118.30742, -118.293953, -118.31...      0
# 9                                      [Male, Female]      0
# 10                                          [No, Yes]      0
# 11                                          [No, Yes]      0
# 12                                          [No, Yes]      0
# 13  [2, 8, 28, 49, 10, 1, 47, 17, 5, 34, 11, 15, 1...      0
# 14                                          [Yes, No]      0
# 15                        [No, Yes, No phone service]      0
# 16                             [DSL, Fiber optic, No]      0
# 17                     [Yes, No, No internet service]      0
# 18                     [Yes, No, No internet service]      0
# 19                     [No, Yes, No internet service]      0
# 20                     [No, Yes, No internet service]      0
# 21                     [No, Yes, No internet service]      0
# 22                     [No, Yes, No internet service]      0
# 23               [Month-to-month, Two year, One year]      0
# 24                                          [Yes, No]      0
# 25  [Mailed check, Electronic check, Bank transfer...      0
# 26  [53.85, 70.7, 99.65, 104.8, 103.7, 55.2, 39.65...      0
# 27  [108.15, 151.65, 820.5, 3046.05, 5036.3, 528.3...      0
# 28                                          [Yes, No]      0
# 29                                             [1, 0]      0
# 30  [86, 67, 84, 89, 78, 100, 92, 77, 97, 74, 66, ...      0
# 31  [3239, 2701, 5372, 5003, 5340, 5925, 5433, 483...      0
# 32  [Competitor made better offer, Moved, Competit...   5174

# %%
data.drop(['CustomerID','Churn Label','Count','Country','State','Zip Code','Lat Long','City'],axis=1,inplace=True)

# %%
data.head()
# Out:
#     Latitude   Longitude  Gender Senior Citizen Partner Dependents  \
# 0  33.964131 -118.272783    Male             No      No         No
# 1  34.059281 -118.307420  Female             No      No        Yes
# 2  34.048013 -118.293953  Female             No      No        Yes
# 3  34.062125 -118.315709  Female             No     Yes        Yes
# 4  34.039224 -118.266293    Male             No      No        Yes
#
#    Tenure Months Phone Service Multiple Lines Internet Service  ...  \
# 0              2           Yes             No              DSL  ...
# 1              2           Yes             No      Fiber optic  ...
# 2              8           Yes            Yes      Fiber optic  ...
# 3             28           Yes            Yes      Fiber optic  ...
# 4             49           Yes            Yes      Fiber optic  ...
#
#   Streaming Movies        Contract Paperless Billing  \
# 0               No  Month-to-month               Yes
# 1               No  Month-to-month               Yes
# 2              Yes  Month-to-month               Yes
# 3              Yes  Month-to-month               Yes
# 4              Yes  Month-to-month               Yes
#
#               Payment Method Monthly Charges Total Charges Churn Value  \
# 0               Mailed check           53.85        108.15           1
# 1           Electronic check           70.70        151.65           1
# 2           Electronic check           99.65         820.5           1
# 3           Electronic check          104.80       3046.05           1
# 4  Bank transfer (automatic)          103.70        5036.3           1
#
#   Churn Score  CLTV                   Churn Reason
# 0          86  3239   Competitor made better offer
# 1          67  2701                          Moved
# 2          86  5372                          Moved
# 3          84  5003                          Moved
# 4          89  5340  Competitor had better devices
#
# [5 rows x 25 columns]

# %%
data_info(data)
# Out:
#                   Col    dtype  n_uniques  \
# 0            Latitude  float64       1652
# 1           Longitude  float64       1651
# 2              Gender   object          2
# 3      Senior Citizen   object          2
# 4             Partner   object          2
# 5          Dependents   object          2
# 6       Tenure Months    int64         73
# 7       Phone Service   object          2
# 8      Multiple Lines   object          3
# 9    Internet Service   object          3
# 10    Online Security   object          3
# 11      Online Backup   object          3
# 12  Device Protection   object          3
# 13       Tech Support   object          3
# 14       Streaming TV   object          3
# 15   Streaming Movies   object          3
# 16           Contract   object          3
# 17  Paperless Billing   object          2
# 18     Payment Method   object          4
# 19    Monthly Charges  float64       1585
# 20      Total Charges   object       6531
# 21        Churn Value    int64          2
# 22        Churn Score    int64         85
# 23               CLTV    int64       3438
# 24       Churn Reason   object         20
#
#                                         Unique Values  Nulls
# 0   [33.964131, 34.059281, 34.048013, 34.062125, 3...      0
# 1   [-118.272783, -118.30742, -118.293953, -118.31...      0
# 2                                      [Male, Female]      0
# 3                                           [No, Yes]      0
# 4                                           [No, Yes]      0
# 5                                           [No, Yes]      0
# 6   [2, 8, 28, 49, 10, 1, 47, 17, 5, 34, 11, 15, 1...      0
# 7                                           [Yes, No]      0
# 8                         [No, Yes, No phone service]      0
# 9                              [DSL, Fiber optic, No]      0
# 10                     [Yes, No, No internet service]      0
# 11                     [Yes, No, No internet service]      0
# 12                     [No, Yes, No internet service]      0
# 13                     [No, Yes, No internet service]      0
# 14                     [No, Yes, No internet service]      0
# 15                     [No, Yes, No internet service]      0
# 16               [Month-to-month, Two year, One year]      0
# 17                                          [Yes, No]      0
# 18  [Mailed check, Electronic check, Bank transfer...      0
# 19  [53.85, 70.7, 99.65, 104.8, 103.7, 55.2, 39.65...      0
# 20  [108.15, 151.65, 820.5, 3046.05, 5036.3, 528.3...      0
# 21                                             [1, 0]      0
# 22  [86, 67, 84, 89, 78, 100, 92, 77, 97, 74, 66, ...      0
# 23  [3239, 2701, 5372, 5003, 5340, 5925, 5433, 483...      0
# 24  [Competitor made better offer, Moved, Competit...   5174

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
data['Contract']=le.fit_transform(data['Contract'])

# %%
data['Churn Value'].value_counts()
# Out:
# Churn Value
# 0    5174
# 1    1869
# Name: count, dtype: int64

# %%
data['Churn Reason'].value_counts()
# Out:
# Churn Reason
# Attitude of support person                   192
# Competitor offered higher download speeds    189
# Competitor offered more data                 162
# Don't know                                   154
# Competitor made better offer                 140
# Attitude of service provider                 135
# Competitor had better devices                130
# Network reliability                          103
# Product dissatisfaction                      102
# Price too high                                98
# Service dissatisfaction                       89
# Lack of self-service on Website               88
# Extra data charges                            57
# Moved                                         53
# Limited range of services                     44
# Long distance charges                         44
# Lack of affordable download/upload speed      44
# Poor expertise of phone support               20
# Poor expertise of online support              19
# Deceased                                       6
# Name: count, dtype: int64

# %%
data['Churn Reason'].fillna("not leave",inplace=True)
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_10616\3116493132.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Churn Reason'].fillna("not leave",inplace=True)

# %%
data_info(data)
# Out:
#                   Col    dtype  n_uniques  \
# 0            Latitude  float64       1652
# 1           Longitude  float64       1651
# 2              Gender   object          2
# 3      Senior Citizen   object          2
# 4             Partner   object          2
# 5          Dependents   object          2
# 6       Tenure Months    int64         73
# 7       Phone Service   object          2
# 8      Multiple Lines   object          3
# 9    Internet Service   object          3
# 10    Online Security   object          3
# 11      Online Backup   object          3
# 12  Device Protection   object          3
# 13       Tech Support   object          3
# 14       Streaming TV   object          3
# 15   Streaming Movies   object          3
# 16           Contract    int32          3
# 17  Paperless Billing   object          2
# 18     Payment Method   object          4
# 19    Monthly Charges  float64       1585
# 20      Total Charges   object       6531
# 21        Churn Value    int64          2
# 22        Churn Score    int64         85
# 23               CLTV    int64       3438
# 24       Churn Reason   object         21
#
#                                         Unique Values  Nulls
# 0   [33.964131, 34.059281, 34.048013, 34.062125, 3...      0
# 1   [-118.272783, -118.30742, -118.293953, -118.31...      0
# 2                                      [Male, Female]      0
# 3                                           [No, Yes]      0
# 4                                           [No, Yes]      0
# 5                                           [No, Yes]      0
# 6   [2, 8, 28, 49, 10, 1, 47, 17, 5, 34, 11, 15, 1...      0
# 7                                           [Yes, No]      0
# 8                         [No, Yes, No phone service]      0
# 9                              [DSL, Fiber optic, No]      0
# 10                     [Yes, No, No internet service]      0
# 11                     [Yes, No, No internet service]      0
# 12                     [No, Yes, No internet service]      0
# 13                     [No, Yes, No internet service]      0
# 14                     [No, Yes, No internet service]      0
# 15                     [No, Yes, No internet service]      0
# 16                                          [0, 2, 1]      0
# 17                                          [Yes, No]      0
# 18  [Mailed check, Electronic check, Bank transfer...      0
# 19  [53.85, 70.7, 99.65, 104.8, 103.7, 55.2, 39.65...      0
# 20  [108.15, 151.65, 820.5, 3046.05, 5036.3, 528.3...      0
# 21                                             [1, 0]      0
# 22  [86, 67, 84, 89, 78, 100, 92, 77, 97, 74, 66, ...      0
# 23  [3239, 2701, 5372, 5003, 5340, 5925, 5433, 483...      0
# 24  [Competitor made better offer, Moved, Competit...      0

# %%
data['Total Charges']=pd.to_numeric(data['Total Charges'],errors='coerce')

# %%
data['Total Charges'].isna().sum()
# Out:
# 11

# %%
data['Total Charges'].fillna(data['Total Charges'].mean(),inplace=True)
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_10616\2330687429.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Total Charges'].fillna(data['Total Charges'].mean(),inplace=True)

# %%
data_info(data)
# Out:
#                   Col    dtype  n_uniques  \
# 0            Latitude  float64       1652
# 1           Longitude  float64       1651
# 2              Gender   object          2
# 3      Senior Citizen   object          2
# 4             Partner   object          2
# 5          Dependents   object          2
# 6       Tenure Months    int64         73
# 7       Phone Service   object          2
# 8      Multiple Lines   object          3
# 9    Internet Service   object          3
# 10    Online Security   object          3
# 11      Online Backup   object          3
# 12  Device Protection   object          3
# 13       Tech Support   object          3
# 14       Streaming TV   object          3
# 15   Streaming Movies   object          3
# 16           Contract    int32          3
# 17  Paperless Billing   object          2
# 18     Payment Method   object          4
# 19    Monthly Charges  float64       1585
# 20      Total Charges  float64       6531
# 21        Churn Value    int64          2
# 22        Churn Score    int64         85
# 23               CLTV    int64       3438
# 24       Churn Reason   object         21
#
#                                         Unique Values  Nulls
# 0   [33.964131, 34.059281, 34.048013, 34.062125, 3...      0
# 1   [-118.272783, -118.30742, -118.293953, -118.31...      0
# 2                                      [Male, Female]      0
# 3                                           [No, Yes]      0
# 4                                           [No, Yes]      0
# 5                                           [No, Yes]      0
# 6   [2, 8, 28, 49, 10, 1, 47, 17, 5, 34, 11, 15, 1...      0
# 7                                           [Yes, No]      0
# 8                         [No, Yes, No phone service]      0
# 9                              [DSL, Fiber optic, No]      0
# 10                     [Yes, No, No internet service]      0
# 11                     [Yes, No, No internet service]      0
# 12                     [No, Yes, No internet service]      0
# 13                     [No, Yes, No internet service]      0
# 14                     [No, Yes, No internet service]      0
# 15                     [No, Yes, No internet service]      0
# 16                                          [0, 2, 1]      0
# 17                                          [Yes, No]      0
# 18  [Mailed check, Electronic check, Bank transfer...      0
# 19  [53.85, 70.7, 99.65, 104.8, 103.7, 55.2, 39.65...      0
# 20  [108.15, 151.65, 820.5, 3046.05, 5036.3, 528.3...      0
# 21                                             [1, 0]      0
# 22  [86, 67, 84, 89, 78, 100, 92, 77, 97, 74, 66, ...      0
# 23  [3239, 2701, 5372, 5003, 5340, 5925, 5433, 483...      0
# 24  [Competitor made better offer, Moved, Competit...      0

# %%
data_info(data)
# Out:
#                   Col    dtype  n_uniques  \
# 0            Latitude  float64       1652
# 1           Longitude  float64       1651
# 2              Gender   object          2
# 3      Senior Citizen   object          2
# 4             Partner   object          2
# 5          Dependents   object          2
# 6       Tenure Months    int64         73
# 7       Phone Service   object          2
# 8      Multiple Lines   object          3
# 9    Internet Service   object          3
# 10    Online Security   object          3
# 11      Online Backup   object          3
# 12  Device Protection   object          3
# 13       Tech Support   object          3
# 14       Streaming TV   object          3
# 15   Streaming Movies   object          3
# 16           Contract    int32          3
# 17  Paperless Billing   object          2
# 18     Payment Method   object          4
# 19    Monthly Charges  float64       1585
# 20      Total Charges  float64       6531
# 21        Churn Value    int64          2
# 22        Churn Score    int64         85
# 23               CLTV    int64       3438
# 24       Churn Reason   object         21
#
#                                         Unique Values  Nulls
# 0   [33.964131, 34.059281, 34.048013, 34.062125, 3...      0
# 1   [-118.272783, -118.30742, -118.293953, -118.31...      0
# 2                                      [Male, Female]      0
# 3                                           [No, Yes]      0
# 4                                           [No, Yes]      0
# 5                                           [No, Yes]      0
# 6   [2, 8, 28, 49, 10, 1, 47, 17, 5, 34, 11, 15, 1...      0
# 7                                           [Yes, No]      0
# 8                         [No, Yes, No phone service]      0
# 9                              [DSL, Fiber optic, No]      0
# 10                     [Yes, No, No internet service]      0
# 11                     [Yes, No, No internet service]      0
# 12                     [No, Yes, No internet service]      0
# 13                     [No, Yes, No internet service]      0
# 14                     [No, Yes, No internet service]      0
# 15                     [No, Yes, No internet service]      0
# 16                                          [0, 2, 1]      0
# 17                                          [Yes, No]      0
# 18  [Mailed check, Electronic check, Bank transfer...      0
# 19  [53.85, 70.7, 99.65, 104.8, 103.7, 55.2, 39.65...      0
# 20  [108.15, 151.65, 820.5, 3046.05, 5036.3, 528.3...      0
# 21                                             [1, 0]      0
# 22  [86, 67, 84, 89, 78, 100, 92, 77, 97, 74, 66, ...      0
# 23  [3239, 2701, 5372, 5003, 5340, 5925, 5433, 483...      0
# 24  [Competitor made better offer, Moved, Competit...      0

# %%
data=pd.get_dummies(data,drop_first=True)
data.head()
# Out:
#     Latitude   Longitude  Tenure Months  Contract  Monthly Charges  \
# 0  33.964131 -118.272783              2         0            53.85
# 1  34.059281 -118.307420              2         0            70.70
# 2  34.048013 -118.293953              8         0            99.65
# 3  34.062125 -118.315709             28         0           104.80
# 4  34.039224 -118.266293             49         0           103.70
#
#    Total Charges  Churn Value  Churn Score  CLTV  Gender_Male  ...  \
# 0         108.15            1           86  3239         True  ...
# 1         151.65            1           67  2701        False  ...
# 2         820.50            1           86  5372        False  ...
# 3        3046.05            1           84  5003        False  ...
# 4        5036.30            1           89  5340         True  ...
#
#    Churn Reason_Limited range of services  Churn Reason_Long distance charges  \
# 0                                   False                               False
# 1                                   False                               False
# 2                                   False                               False
# 3                                   False                               False
# 4                                   False                               False
#
#    Churn Reason_Moved  Churn Reason_Network reliability  \
# 0               False                             False
# 1                True                             False
# 2                True                             False
# 3                True                             False
# 4               False                             False
#
#    Churn Reason_Poor expertise of online support  \
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
#
#    Churn Reason_Poor expertise of phone support  Churn Reason_Price too high  \
# 0                                         False                        False
# 1                                         False                        False
# 2                                         False                        False
# 3                                         False                        False
# 4                                         False                        False
#
#    Churn Reason_Product dissatisfaction  Churn Reason_Service dissatisfaction  \
# 0                                 False                                 False
# 1                                 False                                 False
# 2                                 False                                 False
# 3                                 False                                 False
# 4                                 False                                 False
#
#    Churn Reason_not leave
# 0                   False
# 1                   False
# 2                   False
# 3                   False
# 4                   False
#
# [5 rows x 54 columns]

# %%
X=data.drop(['Churn Value'],axis=1).values
y=data['Churn Value'].values

# %%
from sklearn.model_selection import train_test_split
train_X,test_X,train_y,test_y=train_test_split(X,y,test_size=0.2)

# %%
#fearture scaling 
from sklearn.preprocessing import StandardScaler
sd=StandardScaler()



train_X=sd.fit_transform(train_X)
test_X=sd.transform(test_X)

# %% [raw]
# ## Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model=Sequential()
model.add(Dense(50,activation='relu',input_shape=(train_X.shape[1],)))

model.add(Dense(30,activation='relu'))
model.add(Dense(1,activation='sigmoid'))
model.summary()
# Out:
# c:\Users\dell\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 50)             │         2,700 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 30)             │         1,530 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            31 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,261 (16.64 KB)
#  Trainable params: 4,261 (16.64 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.optimizers import SGD,Adam

# %%
opt=Adam(learning_rate=0.001,beta_1=0.9,beta_2=0.99)
model.compile(loss='binary_crossentropy',optimizer=opt,metrics=['accuracy'])

# %%
history=model.fit(train_X,train_y,validation_split=0.1,batch_size=128,epochs=100)
# Out:
# Epoch 1/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.7232 - loss: 0.5513 - val_accuracy: 0.9876 - val_loss: 0.2169
# Epoch 2/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9821 - loss: 0.1559 - val_accuracy: 0.9947 - val_loss: 0.0462
# Epoch 3/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9933 - loss: 0.0374 - val_accuracy: 0.9965 - val_loss: 0.0173
# Epoch 4/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9973 - loss: 0.0160 - val_accuracy: 0.9982 - val_loss: 0.0094
# Epoch 5/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9990 - loss: 0.0078 - val_accuracy: 0.9982 - val_loss: 0.0058
# Epoch 6/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9996 - loss: 0.0047 - val_accuracy: 1.0000 - val_loss: 0.0038
# Epoch 7/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 1.0000 - val_loss: 0.0026
# Epoch 8/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 1.0000 - val_loss: 0.0018
# Epoch 9/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 9.8277e-04 - val_accuracy: 1.0000 - val_loss: 0.0013
# Epoch 10/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 7.0297e-04 - val_accuracy: 1.0000 - val_loss: 9.3954e-04
# Epoch 11/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 5.1857e-04 - val_accuracy: 1.0000 - val_loss: 6.8625e-04
# Epoch 12/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 3.7980e-04 - val_accuracy: 1.0000 - val_loss: 5.1000e-04
# Epoch 13/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 2.8659e-04 - val_accuracy: 1.0000 - val_loss: 3.9149e-04
# Epoch 14/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 1.8579e-04 - val_accuracy: 1.0000 - val_loss: 2.9509e-04
# Epoch 15/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 1.5085e-04 - val_accuracy: 1.0000 - val_loss: 2.1884e-04
# Epoch 16/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 1.0496e-04 - val_accuracy: 1.0000 - val_loss: 1.7264e-04
# Epoch 17/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 8.0105e-05 - val_accuracy: 1.0000 - val_loss: 1.3403e-04
# Epoch 18/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 5.9327e-05 - val_accuracy: 1.0000 - val_loss: 1.0347e-04
# Epoch 19/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 5.2872e-05 - val_accuracy: 1.0000 - val_loss: 8.1575e-05
# Epoch 20/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 4.2633e-05 - val_accuracy: 1.0000 - val_loss: 6.2379e-05
# Epoch 21/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 3.2969e-05 - val_accuracy: 1.0000 - val_loss: 5.0391e-05
# Epoch 22/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 2.6746e-05 - val_accuracy: 1.0000 - val_loss: 3.8771e-05
# Epoch 23/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 1.8602e-05 - val_accuracy: 1.0000 - val_loss: 3.1406e-05
# Epoch 24/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 1.4440e-05 - val_accuracy: 1.0000 - val_loss: 2.5847e-05
# Epoch 25/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 1.3674e-05 - val_accuracy: 1.0000 - val_loss: 1.9970e-05
# Epoch 26/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 1.1069e-05 - val_accuracy: 1.0000 - val_loss: 1.5919e-05
# Epoch 27/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 7.8309e-06 - val_accuracy: 1.0000 - val_loss: 1.3072e-05
# Epoch 28/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 5.6866e-06 - val_accuracy: 1.0000 - val_loss: 9.9932e-06
# Epoch 29/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 3.8495e-06 - val_accuracy: 1.0000 - val_loss: 8.2404e-06
# Epoch 30/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 3.5806e-06 - val_accuracy: 1.0000 - val_loss: 6.4919e-06
# Epoch 31/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 2.7379e-06 - val_accuracy: 1.0000 - val_loss: 5.2918e-06
# Epoch 32/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 2.2682e-06 - val_accuracy: 1.0000 - val_loss: 4.2235e-06
# Epoch 33/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 1.8502e-06 - val_accuracy: 1.0000 - val_loss: 3.3695e-06
# Epoch 34/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 1.
# Epoch 76/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 1.8787e-09 - val_accuracy: 1.0000 - val_loss: 4.9262e-09
# Epoch 77/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 1.6499e-09 - val_accuracy: 1.0000 - val_loss: 4.6369e-09
# Epoch 78/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 1.3038e-09 - val_accuracy: 1.0000 - val_loss: 4.3831e-09
# Epoch 79/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 1.2195e-09 - val_accuracy: 1.0000 - val_loss: 4.1976e-09
# Epoch 80/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 1.0580e-09 - val_accuracy: 1.0000 - val_loss: 4.0127e-09
# Epoch 81/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 1.0705e-09 - val_accuracy: 1.0000 - val_loss: 3.8463e-09
# Epoch 82/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 9.7170e-10 - val_accuracy: 1.0000 - val_loss: 3.6896e-09
# Epoch 83/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 1.0156e-09 - val_accuracy: 1.0000 - val_loss: 3.5411e-09
# Epoch 84/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 1.1157e-09 - val_accuracy: 1.0000 - val_loss: 3.4111e-09
# Epoch 85/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 1.0881e-09 - val_accuracy: 1.0000 - val_loss: 3.2985e-09
# Epoch 86/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 1.0651e-09 - val_accuracy: 1.0000 - val_loss: 3.1728e-09
# Epoch 87/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 7.5304e-10 - val_accuracy: 1.0000 - val_loss: 3.0857e-09
# Epoch 88/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 8.2338e-10 - val_accuracy: 1.0000 - val_loss: 2.9946e-09
# Epoch 89/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 8.3962e-10 - val_accuracy: 1.0000 - val_loss: 2.9050e-09
# Epoch 90/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 7.3299e-10 - val_accuracy: 1.0000 - val_loss: 2.8205e-09
# Epoch 91/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 8.6505e-10 - val_accuracy: 1.0000 - val_loss: 2.7389e-09
# Epoch 92/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 7.2557e-10 - val_accuracy: 1.0000 - val_loss: 2.6577e-09
# Epoch 93/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 6.3355e-10 - val_accuracy: 1.0000 - val_loss: 2.5775e-09
# Epoch 94/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 5.9043e-10 - val_accuracy: 1.0000 - val_loss: 2.4991e-09
# Epoch 95/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 6.5102e-10 - val_accuracy: 1.0000 - val_loss: 2.4263e-09
# Epoch 96/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 6.9005e-10 - val_accuracy: 1.0000 - val_loss: 2.3556e-09
# Epoch 97/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 6.1190e-10 - val_accuracy: 1.0000 - val_loss: 2.2957e-09
# Epoch 98/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 6.6014e-10 - val_accuracy: 1.0000 - val_loss: 2.2410e-09
# Epoch 99/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 5.7906e-10 - val_accuracy: 1.0000 - val_loss: 2.1794e-09
# Epoch 100/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 5.6046e-10 - val_accuracy: 1.0000 - val_loss: 2.1202e-09

# %%
plt.plot(history.history['accuracy'],label='train')
plt.plot(history.history['val_accuracy'],label='Validation')
plt.legend()
plt.show()

# %%
plt.plot(history.history['loss'],label='train')
plt.plot(history.history['val_loss'],label='Validation')
plt.legend()
plt.show()

# %%
y_pred=model.predict(test_X)
# Out:
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
y_pred_labels = (y_pred > 0.5).astype(int)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_y, y_pred_labels)
print(cm)
# Out:
# [[1052    0]
#  [   0  357]]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Class 0', 'Class 1'], yticklabels=['Class 0', 'Class 1'])
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# # 1. Add Dropout Layers

# %%
from tensorflow.keras.layers import Dropout

model = Sequential()
model.add(Dense(50, activation='relu', input_shape=(train_X.shape[1],)))
model.add(Dropout(0.5))  # 50% dropout

model.add(Dense(30, activation='relu'))
model.add(Dropout(0.5))  # 50% dropout

model.add(Dense(1, activation='sigmoid'))
model.summary()
# Out:
# c:\Users\dell\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                 │ (None, 50)             │         2,700 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 50)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 30)             │         1,530 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 30)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │            31 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,261 (16.64 KB)
#  Trainable params: 4,261 (16.64 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # 2. Use L2 Regularization (Weight Decay)

# %%
from tensorflow.keras.regularizers import l2

model = Sequential()
model.add(Dense(50, activation='relu', kernel_regularizer=l2(0.01), input_shape=(train_X.shape[1],)))
model.add(Dense(30, activation='relu', kernel_regularizer=l2(0.01)))
model.add(Dense(1, activation='sigmoid'))
model.summary()

# %% [markdown]
# # 3. Reduce Model Complexity (Fewer Neurons)

# %% [markdown]
# model = Sequential()
# model.add(Dense(32, activation='relu', input_shape=(train_X.shape[1],)))
# model.add(Dense(16, activation='relu'))
# model.add(Dense(1, activation='sigmoid'))
# model.summary()

# %% [markdown]
# # 4. Use Early Stopping

# %% [markdown]
# from tensorflow.keras.callbacks import EarlyStopping
#
# early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
#
# history = model.fit(train_X, train_y,
#                     epochs=100, batch_size=32,
#                     validation_data=(val_X, val_y),
#                     callbacks=[early_stopping])
