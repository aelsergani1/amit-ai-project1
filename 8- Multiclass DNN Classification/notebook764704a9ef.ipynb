# %%
import os
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# %%
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
download = drive.CreateFile({'id': '19lWsG9i0fYz7mqoULzvODKyIyQLuCTVS'})
download.GetContentFile('fruits-dataset.zip')

# %%
import zipfile
import io
data = zipfile.ZipFile('fruits-dataset.zip', 'r')
data.extractall()

os.rename('archive', 'fruits-dataset') # Just renaming the unzipped folder as it was zipped under the name archive

# %%
train_dir = 'fruits-dataset/train/train'
# validation_dir = 'fruits-dataset/validate/validate'
test_dir = 'fruits-dataset/test/test'

# %%
#Create the dataframe

import pandas as pd
import os

data = []
# print(os.listdir(train_dir))

for fruit_folder in os.listdir(train_dir):
  fruit_path = os.path.join(train_dir, fruit_folder)
  if os.path.isdir(fruit_path):
    for image_file in os.listdir(fruit_path):
      if image_file.lower().endswith(('.jpg', '.jpeg', '.png')):
          image_path = os.path.join(fruit_path, image_file)
          data.append({'image_url': image_path, 'fruit_name': fruit_folder})

df = pd.DataFrame(data)
print(df.head())
# Out:
#                                            image_url  fruit_name
# 0  fruits-dataset/train/train/Pepper Red/Pepper R...  Pepper Red
# 1  fruits-dataset/train/train/Pepper Red/Pepper R...  Pepper Red
# 2  fruits-dataset/train/train/Pepper Red/Pepper R...  Pepper Red
# 3  fruits-dataset/train/train/Pepper Red/Pepper R...  Pepper Red
# 4  fruits-dataset/train/train/Pepper Red/Pepper R...  Pepper Red

# %%
batch_size=64 # Change to 16 or 8
image_size=100
#################################### Data Augmentation ###################################
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint,EarlyStopping

train_datagen=ImageDataGenerator(rescale=1./255,
                                 rotation_range=20,
                                 height_shift_range=0.2,
                                 width_shift_range=0.2,
                                 shear_range=0.2,
                                 horizontal_flip=True,
                                 zoom_range=0.2,
                                fill_mode='nearest')


train_generator=train_datagen.flow_from_directory(train_dir,
                                                  target_size=(image_size,image_size),
                                                  batch_size=batch_size,
                                                  class_mode='categorical')
# Out:
# Found 16854 images belonging to 33 classes.

# %%
from tensorflow.keras import layers, optimizers
from tensorflow.keras import models, Input
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Dropout, Flatten
from tensorflow.keras.models import load_model

model_path = "fruit_classification_model.keras"

if os.path.exists(model_path):
    print("Loading existing model...")
    model = load_model(model_path)
else:
    print("Model not found. Creating a new model...")
    
    model = models.Sequential()
    
    model.add(Input(shape=(image_size, image_size, 3)))
    model.add(layers.Conv2D(64, (3, 3),padding='valid'))
    model.add(layers.Activation('relu'))
    model.add(layers.MaxPooling2D((2, 2)))
    
    model.add(layers.Conv2D(128, (3, 3),padding='valid'))
    model.add(layers.Activation('relu'))
    model.add(layers.MaxPooling2D((2, 2)))
    
    model.add(layers.Conv2D(128, (3, 3),padding='valid'))
    model.add(layers.Activation('relu'))
    model.add(layers.MaxPooling2D((2, 2)))
    
    model.add(layers.Flatten())
    model.add(layers.Dense(100))
    model.add(layers.Activation('relu'))
    model.add(layers.Dropout(0.3))
    model.add(layers.Dense(33))
    model.add(layers.Activation('softmax'))
    
    
    
    checkpointer = ModelCheckpoint(filepath='model.weights.best.hdf5.keras', monitor='val_loss', verbose = 1, save_best_only=True)
    early = EarlyStopping(monitor='accuracy', min_delta=0, patience=10, verbose=1, mode='auto') #val_acc
    model.compile(optimizer=optimizers.Adam(learning_rate=1e-4),loss='categorical_crossentropy',metrics=['accuracy'])
    model.summary()
    
    history=model.fit(train_generator,
                      steps_per_epoch=int(train_generator.samples/train_generator.batch_size),
                      epochs=20,
                      verbose=1,
                      callbacks=[checkpointer, early])
    
    # Save the model for future use
    model.save(model_path)
    print("New model created and saved.")
# Out:
# Loading existing model...

# %%
# Save the full model
model.save("fruit_classification_model.keras")

# %%
class_indices = train_generator.class_indices  # Dictionary mapping class names to indices
index_to_class = {v: k for k, v in class_indices.items()}  # Reverse mapping
index_to_class
# Out:
# {0: 'Apple Braeburn',
#  1: 'Apple Granny Smith',
#  2: 'Apricot',
#  3: 'Avocado',
#  4: 'Banana',
#  5: 'Blueberry',
#  6: 'Cactus fruit',
#  7: 'Cantaloupe',
#  8: 'Cherry',
#  9: 'Clementine',
#  10: 'Corn',
#  11: 'Cucumber Ripe',
#  12: 'Grape Blue',
#  13: 'Kiwi',
#  14: 'Lemon',
#  15: 'Limes',
#  16: 'Mango',
#  17: 'Onion White',
#  18: 'Orange',
#  19: 'Papaya',
#  20: 'Passion Fruit',
#  21: 'Peach',
#  22: 'Pear',
#  23: 'Pepper Green',
#  24: 'Pepper Red',
#  25: 'Pineapple',
#  26: 'Plum',
#  27: 'Pomegranate',
#  28: 'Potato Red',
#  29: 'Raspberry',
#  30: 'Strawberry',
#  31: 'Tomato',
#  32: 'Watermelon'}

# %%
import numpy as np
from tensorflow.keras.preprocessing import image

def predict_fruit(image_path, model, index_to_class, image_size=100):
    img = image.load_img(image_path, target_size=(image_size, image_size))
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0) / 255.0  # Normalize

    predictions = model.predict(img_array)
    predicted_class_index = np.argmax(predictions)
    predicted_class_name = index_to_class[predicted_class_index]

    return predicted_class_name

# Example usage:
# image_path = "path_to_test_image.jpg"
# print("Predicted fruit:", predict_fruit(image_path, model, index_to_class))

# %%
import os

# print(os.listdir(test_dir))
max_count = 100
count = 0
results = []
for fruit_file in os.listdir(test_dir):
    if count > max_count:
        break
    if fruit_file.lower().endswith(('.jpg', '.jpeg', '.png')):
        count += 1
        image_path = os.path.join(test_dir, fruit_file)
        # image_path = os.path.join(fruit_folder, image_file)
        predicted_class = predict_fruit(image_path, model, index_to_class)
        tempResult = {"image": fruit_file, "actual_class": image_path, "predicted_class": predicted_class}
        print(tempResult)
        results.append(tempResult)

# Convert results to a DataFrame for analysis
df_results = pd.DataFrame(results)
print(df_results)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step
# {'image': '3067.jpg', 'actual_class': 'fruits-dataset/test/test/3067.jpg', 'predicted_class': 'Passion Fruit'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# {'image': '4237.jpg', 'actual_class': 'fruits-dataset/test/test/4237.jpg', 'predicted_class': 'Tomato'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# {'image': '2140.jpg', 'actual_class': 'fruits-dataset/test/test/2140.jpg', 'predicted_class': 'Peach'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# {'image': '2052.jpg', 'actual_class': 'fruits-dataset/test/test/2052.jpg', 'predicted_class': 'Apple Granny Smith'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# {'image': '2832.jpg', 'actual_class': 'fruits-dataset/test/test/2832.jpg', 'predicted_class': 'Pomegranate'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# {'image': '4975.jpg', 'actual_class': 'fruits-dataset/test/test/4975.jpg', 'predicted_class': 'Peach'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# {'image': '3958.jpg', 'actual_class': 'fruits-dataset/test/test/3958.jpg', 'predicted_class': 'Onion White'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# {'image': '3522.jpg', 'actual_class': 'fruits-dataset/test/test/3522.jpg', 'predicted_class': 'Potato Red'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# {'image': '0976.jpg', 'actual_class': 'fruits-dataset/test/test/0976.jpg', 'predicted_class': 'Cantaloupe'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# {'image': '4966.jpg', 'actual_class': 'fruits-dataset/test/test/4966.jpg', 'predicted_class': 'Pepper Red'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# {'image': '0042.jpg', 'actual_class': 'fruits-dataset/test/test/0042.jpg', 'predicted_class': 'Potato Red'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# {'image': '1276.jpg', 'actual_class': 'fruits-dataset/test/test/1276.jpg', 'predicted_class': 'Plum'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# {'image': '2792.jpg', 'actual_class': 'fruits-dataset/test/test/2792.jpg', 'predicted_class': 'Cherry'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# {'image': '1000.jpg', 'actual_class': 'fruits-dataset/test/test/1000.jpg', 'predicted_class': 'Pomegranate'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# {'image': '0875.jpg', 'actual_class': 'fruits-dataset/test/test/0875.jpg', 'predicted_class': 'Cactus fruit'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# {'image': '5252.jpg', 'actual_class': 'fruits-dataset/test/test/5252.jpg', 'predicted_class': 'Corn'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# {'image': '4212.jpg', 'actual_class': 'fruits-dataset/test/test/4212.jpg', 'predicted_class': 'Watermelon'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# {'image': '0654.jpg', 'actual_class': 'fruits-dataset/test/test/0654.jpg', 'predicted_class': 'Blueberry'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# {'image': '3762.jpg', 'actual_class': 'fruits-dataset/test/test/3762.jpg', 'predicted_class': 'Mango'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# {'image': '4769.jpg', 'actual_class': 'fruits-dataset/test/test/4769.jpg', 'predicted_class': 'Cactus fruit'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# {'image': '5016.jpg', 'actual_class': 'fruits-dataset/test/test/5016.jpg', 'predicted_class': 'Lemon'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# {'image': '1463.jpg', 'actual_class': 'fruits-dataset/test/test/1463.jpg', 'predicted_class': 'Apple Granny Smith'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# {'image': '1119.jpg', 'actual_class': 'fruits-dataset/test/test/1119.jpg', 'predicted_class': 'Apple Braeburn'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# {'image': '0657.jpg', 'actual_class': 'fruits-dataset/test/test/0657.jpg', 'predicted_class': 'Blueberry'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# {'image': '3582.jpg', 'actual_class': 'fruits-dataset/test/test/3582.jpg', 'predicted_class': 'Clementine'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# {'image': '0054.jpg', 'actual_class': 'fruits-dataset/test/test/0054.jpg', 'predicted_class': 'Clementine'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# {'image': '0129.jpg', 'actual_class': 'fruits-dataset/test/test/0129.jpg', 'predicted_class': 'Pear'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# {'image': '0505.jpg', 'actual_class': 'fruits-dataset/test/test/0505.jpg', 'predicted_class': 'Pineapple'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# {'image': '0966.jpg', 'actual_class': 'fruits-dataset/test/test/0966.jpg', 'predicted_class': 'Peach'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# {'image': '5437.jpg', 'actual_class': 'fruits-dataset/test/test/5437.jpg', 'predicted_class': 'Apple Braeburn'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# {'image': '2667.jpg', 'actual_class': 'fruits-dataset/test/test/2667.jpg', 'predicted_class': 'Cactus fruit'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# {'image': '3445.jpg', 'actual_class': 'fruits-dataset/test/test/3445.jpg', 'predicted_class': 'Clementine'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# {'image': '3187.jpg', 'actual_class': 'fruits-dataset/test/test/3187.jpg', 'predicted_class': 'Peach'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# {'image': '2112.jpg', 'actual_class': 'fruits-dataset/test/test/2112.jpg', 'predicted_class': 'Avocado'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# {'image': '5527.jpg', 'actual_class': 'fruits-dataset/test/test/5527.jpg', 'predicted_class': 'Strawberry'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# {'image': '3937.jpg', 'actual_class': 'fruits-dataset/test/test/3937.jpg', 'predicted_class': 'Kiwi'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# {'image': '3781.jpg', 'actual_class': 'fruits-dataset/test/test/3781.jpg', 'predicted_class': 'Apple Braeburn'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# {'image': '0123.jpg', 'actual_class': 'fruits-dataset/test/test/0123.jpg', 'predicted_class': 'Tomato'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# {'image': '1280.jpg', 'actual_class': 'fruits-dataset/test/test/1280.jpg', 'predicted_class': 'Apricot'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# {'image': '1129.jpg', 'actual_class': 'fruits-dataset/test/test/1129.jpg', 'predicted_class': 'Kiwi'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# {'image': '3378.jpg', 'actual_class': 'fruits-dataset/test/test/3378.jpg', 'predicted_class': 'Grape Blue'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# {'image': '1099.jpg', 'actual_class': 'fruits-dataset/test/test/1099.jpg', 'predicted_class': 'Clementine'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# {'image': '2503.jpg', 'actual_class': 'fruits-dataset/test/test/2503.jpg', 'predicted_class': 'Apple Braeburn'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# {'image': '4262.jpg', 'actual_class': 'fruits-dataset/test/test/4262.jpg', 'predicted_class': 'Blueberry'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# {'image': '5473.jpg', 'actual_class': 'fruits-dataset/test/test/5473.jpg', 'predicted_class': 'Apple Granny Smith'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# {'image': '0893.jpg', 'actual_class': 'fruits-dataset/test/test/0893.jpg', 'predicted_class': 'Lemon'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# {'image': '4607.jpg', 'actual_class': 'fruits-dataset/test/test/4607.jpg', 'predicted_class': 'Peach'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# {'image': '4829.jpg', 'actual_class': 'fruits-dataset/test/test/4829.jpg', 'predicted_class': 'Lemon'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# {'image': '2161.jpg', 'actual_class': 'fruits-dataset/test/test/2161.jpg', 'predicted_class': 'Pepper Red'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# {'image': '5307.jpg', 'actual_class': 'fruits-dataset/test/test/5307.jpg', 'predicted_class': 'Papaya'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# {'image': '5122.jpg', 'actual_class': 'fruits-dataset/test/test/5122.jpg', 'predicted_class': 'Cactus fruit'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# {'image': '2051.jpg', 'actual_class': 'fruits-dataset/test/test/2051.jpg', 'predicted_class': 'Avocado'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# {'image': '3152.jpg', 'actual_class': 'fruits-dataset/test/test/3152.jpg', 'predicted_class': 'Grape Blue'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# {'image': '1424.jpg', 'actual_class': 'fruits-dataset/test/test/1424.jpg', 'predicted_class': 'Limes'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# {'image': '1634.jpg', 'actual_class': 'fruits-dataset/test/test/1634.jpg', 'predicted_class': 'Pineapple'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# {'image': '5507.jpg', 'actual_class': 'fruits-dataset/test/test/5507.jpg', 'predicted_class': 'Banana'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# {'image': '2256.jpg', 'actual_class': 'fruits-dataset/test/test/2256.jpg', 'predicted_class': 'Cactus fruit'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# {'image': '4183.jpg', 'actual_class': 'fruits-dataset/test/test/4183.jpg', 'predicted_class': 'Cherry'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# {'image': '1229.jpg', 'actual_class': 'fruits-dataset/test/test/1229.jpg', 'predicted_class': 'Cucumber Ripe'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# {'image': '1455.jpg', 'actual_class': 'fruits-dataset/test/test/1455.jpg', 'predicted_class': 'Pepper Red'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# {'image': '2646.jpg', 'actual_class': 'fruits-dataset/test/test/2646.jpg', 'predicted_class': 'Apple Granny Smith'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# {'image': '2144.jpg', 'actual_class': 'fruits-dataset/test/test/2144.jpg', 'predicted_class': 'Potato Red'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# {'image': '3208.jpg', 'actual_class': 'fruits-dataset/test/test/3208.jpg', 'predicted_class': 'Clementine'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# {'image': '2331.jpg', 'actual_class': 'fruits-dataset/test/test/2331.jpg', 'predicted_class': 'Lemon'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# {'image': '2546.jpg', 'actual_class': 'fruits-dataset/test/test/2546.jpg', 'predicted_class': 'Tomato'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# {'image': '2902.jpg', 'actual_class': 'fruits-dataset/test/test/2902.jpg', 'predicted_class': 'Pear'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# {'image': '0580.jpg', 'actual_class': 'fruits-dataset/test/test/0580.jpg', 'predicted_class': 'Strawberry'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# {'image': '1148.jpg', 'actual_class': 'fruits-dataset/test/test/1148.jpg', 'predicted_class': 'Onion White'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# {'image': '2252.jpg', 'actual_class': 'fruits-dataset/test/test/2252.jpg', 'predicted_class': 'Cucumber Ripe'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# {'image': '4703.jpg', 'actual_class': 'fruits-dataset/test/test/4703.jpg', 'predicted_class': 'Cantaloupe'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# {'image': '1829.jpg', 'actual_class': 'fruits-dataset/test/test/1829.jpg', 'predicted_class': 'Grape Blue'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# {'image': '4334.jpg', 'actual_class': 'fruits-dataset/test/test/4334.jpg', 'predicted_class': 'Pear'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# {'image': '0912.jpg', 'actual_class': 'fruits-dataset/test/test/0912.jpg', 'predicted_class': 'Corn'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# {'image': '3207.jpg', 'actual_class': 'fruits-dataset/test/test/3207.jpg', 'predicted_class': 'Cantaloupe'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# {'image': '1925.jpg', 'actual_class': 'fruits-dataset/test/test/1925.jpg', 'predicted_class': 'Orange'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# {'image': '2183.jpg', 'actual_class': 'fruits-dataset/test/test/2183.jpg', 'predicted_class': 'Watermelon'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# {'image': '1385.jpg', 'actual_class': 'fruits-dataset/test/test/1385.jpg', 'predicted_class': 'Cherry'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# {'image': '2871.jpg', 'actual_class': 'fruits-dataset/test/test/2871.jpg', 'predicted_class': 'Onion White'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# {'image': '3253.jpg', 'actual_class': 'fruits-dataset/test/test/3253.jpg', 'predicted_class': 'Tomato'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# {'image': '1153.jpg', 'actual_class': 'fruits-dataset/test/test/1153.jpg', 'predicted_class': 'Grape Blue'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# {'image': '2936.jpg', 'actual_class': 'fruits-dataset/test/test/2936.jpg', 'predicted_class': 'Cactus fruit'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# {'image': '4326.jpg', 'actual_class': 'fruits-dataset/test/test/4326.jpg', 'predicted_class': 'Grape Blue'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# {'image': '5255.jpg', 'actual_class': 'fruits-dataset/test/test/5255.jpg', 'predicted_class': 'Corn'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# {'image': '3843.jpg', 'actual_class': 'fruits-dataset/test/test/3843.jpg', 'predicted_class': 'Mango'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# {'image': '3243.jpg', 'actual_class': 'fruits-dataset/test/test/3243.jpg', 'predicted_class': 'Lemon'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# {'image': '5522.jpg', 'actual_class': 'fruits-dataset/test/test/5522.jpg', 'predicted_class': 'Lemon'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# {'image': '3744.jpg', 'actual_class': 'fruits-dataset/test/test/3744.jpg', 'predicted_class': 'Pineapple'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# {'image': '3278.jpg', 'actual_class': 'fruits-dataset/test/test/3278.jpg', 'predicted_class': 'Cantaloupe'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# {'image': '4944.jpg', 'actual_class': 'fruits-dataset/test/test/4944.jpg', 'predicted_class': 'Avocado'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# {'image': '1372.jpg', 'actual_class': 'fruits-dataset/test/test/1372.jpg', 'predicted_class': 'Raspberry'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# {'image': '4864.jpg', 'actual_class': 'fruits-dataset/test/test/4864.jpg', 'predicted_class': 'Cantaloupe'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# {'image': '3411.jpg', 'actual_class': 'fruits-dataset/test/test/3411.jpg', 'predicted_class': 'Tomato'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# {'image': '2106.jpg', 'actual_class': 'fruits-dataset/test/test/2106.jpg', 'predicted_class': 'Raspberry'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# {'image': '0651.jpg', 'actual_class': 'fruits-dataset/test/test/0651.jpg', 'predicted_class': 'Passion Fruit'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# {'image': '3297.jpg', 'actual_class': 'fruits-dataset/test/test/3297.jpg', 'predicted_class': 'Pomegranate'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# {'image': '2668.jpg', 'actual_class': 'fruits-dataset/test/test/2668.jpg', 'predicted_class': 'Orange'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# {'image': '2245.jpg', 'actual_class': 'fruits-dataset/test/test/2245.jpg', 'predicted_class': 'Apple Granny Smith'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# {'image': '4686.jpg', 'actual_class': 'fruits-dataset/test/test/4686.jpg', 'predicted_class': 'Onion White'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# {'image': '3102.jpg', 'actual_class': 'fruits-dataset/test/test/3102.jpg', 'predicted_class': 'Peach'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# {'image': '3511.jpg', 'actual_class': 'fruits-dataset/test/test/3511.jpg', 'predicted_class': 'Papaya'}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# {'image': '2718.jpg', 'actual_class': 'fruits-dataset/test/test/2718.jpg', 'predicted_class': 'Peach'}
#         image                       actual_class     predicted_class
# 0    3067.jpg  fruits-dataset/test/test/3067.jpg       Passion Fruit
# 1    4237.jpg  fruits-dataset/test/test/4237.jpg              Tomato
# 2    2140.jpg  fruits-dataset/test/test/2140.jpg               Peach
# 3    2052.jpg  fruits-dataset/test/test/2052.jpg  Apple Granny Smith
# 4    2832.jpg  fruits-dataset/test/test/2832.jpg         Pomegranate
# ..        ...                                ...                 ...
# 96   2245.jpg  fruits-dataset/test/test/2245.jpg  Apple Granny Smith
# 97   4686.jpg  fruits-dataset/test/test/4686.jpg         Onion White
# 98   3102.jpg  fruits-dataset/test/test/3102.jpg               Peach
# 99   3511.jpg  fruits-dataset/test/test/3511.jpg              Papaya
# 100  2718.jpg  fruits-dataset/test/test/2718.jpg               Peach
#
# [101 rows x 3 columns]
